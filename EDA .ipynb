# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
file_path = " student_oerformance_data_.csv"

# %%
df = pd.read_csv(r"C:\Users\anjan\Downloads\Student_performance_data _.csv")

# %%
print(df.shape)
# Out:
# (2392, 15)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB
# None

# %%
print(df.describe())
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %%
df['Age'].hist(bins=35, edgecolor='red')
# Out:
# <Axes: >

# %%
df['Age'].hist(bins=8, color='lightgreen', edgecolor='black')
plt.title("Age Distribution")
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
sns.scatterplot(x='StudyTimeWeekly', y='Gender', data=df)
plt.title('StudyTime vs Gender')
plt.show()

# %%
    plt.scatter(df['StudyTimeWeekly'], df['GPA'], alpha=0.6, color='purple')
    plt.title("GPA vs StudyTimeWeekly")
# Out:
# Text(0.5, 1.0, 'GPA vs StudyTimeWeekly')

# %%
plt.scatter(df['Age'], df['GPA'], alpha=0.6, color='orange')
plt.title("GPA vs Age")
# Out:
# Text(0.5, 1.0, 'GPA vs Age')

# %%
    df.groupby('ParentalSupport')['GPA'].mean().plot(kind='bar', color='teal')
    plt.title("Mean GPA by Parental Support")
# Out:
# Text(0.5, 1.0, 'Mean GPA by Parental Support')

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="YlGnBu")
plt.title("Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
df['Gender'].value_counts().plot(kind='bar', color='lightcoral')
plt.title("Gender Distribution")
# Out:
# Text(0.5, 1.0, 'Gender Distribution')

# %%
df.boxplot(column='GPA', by='Gender')
# Out:
# <Axes: title={'center': 'GPA'}, xlabel='Gender'>

# %%
    pivot = pd.pivot_table(df, values='GPA', index='StudyTimeWeekly', columns='ParentalSupport', aggfunc='mean')
    sns.heatmap(pivot, annot=True, cmap="coolwarm", fmt=".2f")
    plt.title("Mean GPA by StudyTimeWeekly & Parental Support")
# Out:
# Text(0.5, 1.0, 'Mean GPA by StudyTimeWeekly & Parental Support')
